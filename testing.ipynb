# %%
from ollama import chat

# %%
# !ollama pull gemma4
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest
# pulling 4c27e0f5b5ad: 100% ▕██████████████████▏ 9.6 GB
# pulling 7339fa418c9a: 100% ▕██████████████████▏  11 KB
# pulling 56380ca2ab89: 100% ▕██████████████████▏   42 B
# pulling f0988ff50a24: 100% ▕██████████████████▏  473 B
# verifying sha256 digest
# writing manifest
# success

# %%
stream = chat(model='gemma4', \
              messages=[{'role': 'user', 'content': 'what color is the sun'}], \
                stream=True)

# %% [markdown]
# pdf thing

# %% [markdown]
# rag time

# %%
def rag_chunking(text, chunk_size=500, overlap=50):
    chunks = []
    start = 0
    while start < len(text):
